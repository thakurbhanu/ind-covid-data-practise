# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/bhanu/ind-covid-data-practise/covid19india.csv')



# correcting time format according to ISO standards

time_format= '%d/%m/%y'
df['Date'] = pd.to_datetime(df['Date'], format=time_format)

# %%
df.head()
# Out:
#    Sno       Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1 2020-01-30               Kerala                        1
# 1    2 2020-01-31               Kerala                        1
# 2    3 2020-02-01               Kerala                        2
# 3    4 2020-02-02               Kerala                        3
# 4    5 2020-02-03               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
df['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Pondicherry', 'West Bengal', 'Chattisgarh',
#        'Chandigarh', 'Chhattisgarh', 'Gujarat', 'Puducherry',
#        'Himachal Pradesh', 'Madhya Pradesh', 'Bihar', 'Manipur',
#        'Mizoram', 'Andaman and Nicobar Islands', 'Goa'], dtype=object)

# %%
df.columns
# Out:
# Index(['Sno', 'Date', 'State/UnionTerritory', 'ConfirmedIndianNational',
#        'ConfirmedForeignNational', 'Cured', 'Deaths'],
#       dtype='object')

# %%
df2 = df.pivot( index = 'Date', columns = 'State/UnionTerritory', values = 'ConfirmedIndianNational')

# %%
df2.head()
# Out:
# State/UnionTerritory  Andaman and Nicobar Islands  Andhra Pradesh  Bihar  \
# Date
# 2020-01-30                                    NaN             NaN    NaN
# 2020-01-31                                    NaN             NaN    NaN
# 2020-02-01                                    NaN             NaN    NaN
# 2020-02-02                                    NaN             NaN    NaN
# 2020-02-03                                    NaN             NaN    NaN
#
# State/UnionTerritory  Chandigarh  Chattisgarh  Chhattisgarh  Delhi  Goa  \
# Date
# 2020-01-30                   NaN          NaN           NaN    NaN  NaN
# 2020-01-31                   NaN          NaN           NaN    NaN  NaN
# 2020-02-01                   NaN          NaN           NaN    NaN  NaN
# 2020-02-02                   NaN          NaN           NaN    NaN  NaN
# 2020-02-03                   NaN          NaN           NaN    NaN  NaN
#
# State/UnionTerritory  Gujarat  Haryana  ...  Odisha  Pondicherry  Puducherry  \
# Date                                    ...
# 2020-01-30                NaN      NaN  ...     NaN          NaN         NaN
# 2020-01-31                NaN      NaN  ...     NaN          NaN         NaN
# 2020-02-01                NaN      NaN  ...     NaN          NaN         NaN
# 2020-02-02                NaN      NaN  ...     NaN          NaN         NaN
# 2020-02-03                NaN      NaN  ...     NaN          NaN         NaN
#
# State/UnionTerritory  Punjab  Rajasthan  Tamil Nadu  Telengana  Uttar Pradesh  \
# Date
# 2020-01-30               NaN        NaN         NaN        NaN            NaN
# 2020-01-31               NaN        NaN         NaN        NaN            NaN
# 2020-02-01               NaN        NaN         NaN        NaN            NaN
# 2020-02-02               NaN        NaN         NaN        NaN            NaN
# 2020-02-03               NaN        NaN         NaN        NaN            NaN
#
# State/UnionTerritory  Uttarakhand  West Bengal
# Date
# 2020-01-30                    NaN          NaN
# 2020-01-31                    NaN          NaN
# 2020-02-01                    NaN          NaN
# 2020-02-02                    NaN          NaN
# 2020-02-03                    NaN          NaN
#
# [5 rows x 29 columns]

# %%
df2.index
# Out:
# DatetimeIndex(['2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#                '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#                '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#                '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#                '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#                '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#                '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#                '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#                '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#                '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#                '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#                '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#                '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
#                '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#                '2020-03-26', '2020-03-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df2['Pondicherry']
# Out:
# Date
# 2020-01-30    NaN
# 2020-01-31    NaN
# 2020-02-01    NaN
# 2020-02-02    NaN
# 2020-02-03    NaN
# 2020-02-04    NaN
# 2020-02-05    NaN
# 2020-02-06    NaN
# 2020-02-07    NaN
# 2020-02-08    NaN
# 2020-02-09    NaN
# 2020-02-10    NaN
# 2020-02-11    NaN
# 2020-02-12    NaN
# 2020-02-13    NaN
# 2020-02-14    NaN
# 2020-02-15    NaN
# 2020-02-16    NaN
# 2020-02-17    NaN
# 2020-02-18    NaN
# 2020-02-19    NaN
# 2020-02-20    NaN
# 2020-02-21    NaN
# 2020-02-22    NaN
# 2020-02-23    NaN
# 2020-02-24    NaN
# 2020-02-25    NaN
# 2020-02-26    NaN
# 2020-02-27    NaN
# 2020-02-28    NaN
# 2020-02-29    NaN
# 2020-03-01    NaN
# 2020-03-02    NaN
# 2020-03-03    NaN
# 2020-03-04    NaN
# 2020-03-05    NaN
# 2020-03-06    NaN
# 2020-03-07    NaN
# 2020-03-08    NaN
# 2020-03-09    NaN
# 2020-03-10    NaN
# 2020-03-11    NaN
# 2020-03-12    NaN
# 2020-03-13    NaN
# 2020-03-14    NaN
# 2020-03-15    NaN
# 2020-03-16    NaN
# 2020-03-17    NaN
# 2020-03-18    1.0
# 2020-03-19    1.0
# 2020-03-20    NaN
# 2020-03-21    NaN
# 2020-03-22    NaN
# 2020-03-23    NaN
# 2020-03-24    NaN
# 2020-03-25    NaN
# 2020-03-26    NaN
# 2020-03-27    NaN
# Name: Pondicherry, dtype: float64

# %%
df2.Puducherry
# Out:
# Date
# 2020-01-30    NaN
# 2020-01-31    NaN
# 2020-02-01    NaN
# 2020-02-02    NaN
# 2020-02-03    NaN
# 2020-02-04    NaN
# 2020-02-05    NaN
# 2020-02-06    NaN
# 2020-02-07    NaN
# 2020-02-08    NaN
# 2020-02-09    NaN
# 2020-02-10    NaN
# 2020-02-11    NaN
# 2020-02-12    NaN
# 2020-02-13    NaN
# 2020-02-14    NaN
# 2020-02-15    NaN
# 2020-02-16    NaN
# 2020-02-17    NaN
# 2020-02-18    NaN
# 2020-02-19    NaN
# 2020-02-20    NaN
# 2020-02-21    NaN
# 2020-02-22    NaN
# 2020-02-23    NaN
# 2020-02-24    NaN
# 2020-02-25    NaN
# 2020-02-26    NaN
# 2020-02-27    NaN
# 2020-02-28    NaN
# 2020-02-29    NaN
# 2020-03-01    NaN
# 2020-03-02    NaN
# 2020-03-03    NaN
# 2020-03-04    NaN
# 2020-03-05    NaN
# 2020-03-06    NaN
# 2020-03-07    NaN
# 2020-03-08    NaN
# 2020-03-09    NaN
# 2020-03-10    NaN
# 2020-03-11    NaN
# 2020-03-12    NaN
# 2020-03-13    NaN
# 2020-03-14    NaN
# 2020-03-15    NaN
# 2020-03-16    NaN
# 2020-03-17    NaN
# 2020-03-18    NaN
# 2020-03-19    NaN
# 2020-03-20    1.0
# 2020-03-21    1.0
# 2020-03-22    1.0
# 2020-03-23    1.0
# 2020-03-24    1.0
# 2020-03-25    1.0
# 2020-03-26    1.0
# 2020-03-27    1.0
# Name: Puducherry, dtype: float64

# %%
fig, ax = plt.subplots()

ax.plot(df2.index, df2['Maharashtra'])
ax.plot(df2.index, df2['Kerala'])

plt.show()
