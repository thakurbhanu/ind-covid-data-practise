# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/home/bhanu/ind-covid-data-practise/IndividualDetails.csv', index_col='diagnosed_date')

#time_format= '%d/%m/%y'
#df['diagnosed_date'] = pd.to_datetime(df['diagnosed_date'], format=time_format)

# %%
df2 = df.dropna()

# %%
df2.head()
# Out:
#                 id government_id age gender             detected_city  \
# diagnosed_date
# 30/01/2020       0      KL-TS-P1  20      F                  Thrissur
# 02/03/2020       3         DL-P1  45      M  East Delhi (Mayur Vihar)
# 05/03/2020      28         DL-P2  27      M                 Janakpuri
# 07/03/2020      33         TN-P1  45      M              Kancheepuram
# 08/03/2020      34      KL-PT-P1  24      M                     Ranni
#
#                detected_district detected_state nationality current_status  \
# diagnosed_date
# 30/01/2020              Thrissur         Kerala       India      Recovered
# 02/03/2020            East Delhi          Delhi       India      Recovered
# 05/03/2020      South West Delhi          Delhi       India   Hospitalized
# 07/03/2020          Kancheepuram     Tamil Nadu       India      Recovered
# 08/03/2020        Pathanamthitta         Kerala       India   Hospitalized
#
#                status_change_date  \
# diagnosed_date
# ...

# %%
df2.columns
# Out:
# Index(['id', 'government_id', 'age', 'gender', 'detected_city',
#        'detected_district', 'detected_state', 'nationality', 'current_status',
#        'status_change_date', 'notes'],
#       dtype='object')

# %%
df3 = df2.drop(columns=['id', 'government_id','detected_city', 'detected_district', 'current_status', 'status_change_date', 'notes'])

# %%
df3.head()
# Out:
#                age gender detected_state nationality
# diagnosed_date
# 30/01/2020      20      F         Kerala       India
# 02/03/2020      45      M          Delhi       India
# 05/03/2020      27      M          Delhi       India
# 07/03/2020      45      M     Tamil Nadu       India
# 08/03/2020      24      M         Kerala       India

# %%
df4 = df3.head()

# %%
df4
# Out:
#                age gender detected_state nationality
# diagnosed_date
# 30/01/2020      20      F         Kerala       India
# 02/03/2020      45      M          Delhi       India
# 05/03/2020      27      M          Delhi       India
# 07/03/2020      45      M     Tamil Nadu       India
# 08/03/2020      24      M         Kerala       India
